# %% [markdown]
# # Cyclistic Trip Data Analysis

# %% [markdown]
# Collecting the last 12 months worth of Cyclistic trip data.<br>
# Data was downloaded as zip files from [Divvy](https://divvy-tripdata.s3.amazonaws.com/index.html) under this [license](https://www.divvybikes.com/data-license-agreement).<br>
# (_The data was made available by Motivate International Inc._)

# %%
# Importing required libraries
import os # for interacting with the operating system
import pandas as pd # for working with tabular data

# %%
# Get csv file path
dir_path = os.getcwd() + "\\Original_data_20221127\\"

# %%
# Get a list of all the trip data csv files
tripdata_files = os.listdir(dir_path)
tripdata_files
# Out:
# ['202111-divvy-tripdata.csv',
#  '202112-divvy-tripdata.csv',
#  '202201-divvy-tripdata.csv',
#  '202202-divvy-tripdata.csv',
#  '202203-divvy-tripdata.csv',
#  '202204-divvy-tripdata.csv',
#  '202205-divvy-tripdata.csv',
#  '202206-divvy-tripdata.csv',
#  '202207-divvy-tripdata.csv',
#  '202208-divvy-tripdata.csv',
#  '202209-divvy-publictripdata.csv',
#  '202210-divvy-tripdata.csv']

# %% [markdown]
# ## Check for the correct number of files

# %%
# Check length of the list, should be 12 files representing the last 12 months trip data
len(tripdata_files)
# Out:
# 12

# %% [markdown]
# ### Inspect each file

# %%
file_path = dir_path + tripdata_files[0]
trip_data = pd.read_csv(file_path)
trip_data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  7C00A93E10556E47  electric_bike  2021-11-27 13:27:38  2021-11-27 13:46:38
# 1  90854840DFD508BA  electric_bike  2021-11-27 13:38:25  2021-11-27 13:56:10
# 2  0A7D10CDD144061C  electric_bike  2021-11-26 22:03:34  2021-11-26 22:05:56
# 3  2F3BE33085BCFF02  electric_bike  2021-11-27 09:56:49  2021-11-27 10:01:50
# 4  D67B4781A19928D4  electric_bike  2021-11-26 19:09:28  2021-11-26 19:30:41
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# 0      41.93     -87.72    41.96   -87.73        casual
# 1      41.96     -87.70    41.92   -87.70        casual
# 2      41.96     -87.70    41.96   -87.70        casual
# 3      41.94     -87.79    41.93   -87.79        casual
# 4      41.90     -87.63    41.88   -87.62        casual

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  object
#  3   ended_at            359978 non-null  object
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 35.7+ MB

# %% [markdown]
# ### Dataset has null values for:
# - 'start_station_name'
# - 'start_station_id'
# - 'end_station_name'
# - 'end_station_id'
# - 'end_lat'
# - 'end_lng'

# %% [markdown]
# Can we get the missing data?<br>
# Can we use the 'start_lat' and 'start_lng' to find the 'start_station_name' and 'start_station_id'?<br>
# Is the dat even needed for my analysis?<br>
# <br>
# *Note: 'started_at' and 'ended_at' need to be split and converted to date and time data types respectively.*

# %% [markdown]
# # Check summary statistics

# %%
trip_data.describe(include="all")
# Out:
#                  ride_id  rideable_type           started_at  \
# count             359978         359978               359978
# unique            359978              3               320477
# top     7C00A93E10556E47  electric_bike  2021-11-07 15:52:47
# freq                   1         198325                    6
# mean                 NaN            NaN                  NaN
# std                  NaN            NaN                  NaN
# min                  NaN            NaN                  NaN
# 25%                  NaN            NaN                  NaN
# 50%                  NaN            NaN                  NaN
# 75%                  NaN            NaN                  NaN
# max                  NaN            NaN                  NaN
#
#                    ended_at   start_station_name start_station_id  \
# count                359978               284688           284688
# unique               320071                  815              815
# top     2021-11-16 09:56:18  Ellis Ave & 60th St     KA1503000014
# freq                     14                 3095             3095
# mean                    NaN                  NaN              NaN
# std                     NaN                  NaN              NaN
# min                     NaN                  NaN              NaN
# 25%                     NaN                  NaN              NaN
# 50%                     NaN                  NaN              NaN
# 75%                     NaN                  NaN              NaN
# max                     NaN                  NaN              NaN
#
#            end_station_name end_station_id      start_lat      start_lng  \
# count                280791         280791  359978.000000  359978.000000
# unique                  805            805            NaN            NaN
# top     Ellis Ave & 60th St   KA1503000014            NaN            NaN
# freq                   3002           3002            NaN            NaN
# mean                    NaN            NaN      41.893770     -87.647342
# std                     NaN            NaN       0.052579       0.033397
# min                     NaN            NaN      41.648501     -87.840000
# 25%                     NaN            NaN      41.877726     -87.663832
# 50%                     NaN            NaN      41.894666     -87.643107
# 75%                     NaN            NaN      41.925602     -87.627722
# max                     NaN            NaN      42.070000     -87.528232
#
#               end_lat        end_lng member_casual
# count   359787.000000  359787.000000        359978
# unique            NaN            NaN             2
# top               NaN            NaN        member
# freq              NaN            NaN        253049
# mean        41.893900     -87.647543           NaN
# std          0.052618       0.033608           NaN
# min         41.390000     -88.970000           NaN
# 25%         41.877850     -87.663923           NaN
# 50%         41.894683     -87.643118           NaN
# 75%         41.925602     -87.627754           NaN
# max         42.120000     -87.528232           NaN

# %%
trip_data["rideable_type"].value_counts(normalize=True)
# Out:
# electric_bike    0.550936
# classic_bike     0.427912
# docked_bike      0.021151
# Name: rideable_type, dtype: float64

# %%
trip_data["member_casual"].value_counts(normalize=True)
# Out:
# member    0.702957
# casual    0.297043
# Name: member_casual, dtype: float64

# %% [markdown]
# Quick observations:
# - There are 3 types of bikes available
# - Electric bikes are used 55% of the time for rides
# - Members make up 70% of our customer base

# %%
trip_data.groupby(["rideable_type", "member_casual"])["member_casual"].count().unstack()
# Out:
# member_casual   casual    member
# rideable_type
# classic_bike   31866.0  122173.0
# docked_bike     7614.0       NaN
# electric_bike  67449.0  130876.0

# %% [markdown]
# Members do not use docked bikes.<br>
# While memebers use electric bikes more, there is not a by a significant margin.<br>
# Casual riders use electric bikes more than 50% of the time.<br>

# %%
# Transform the 'started_at' and 'ended_at' to datetime objects
trip_data["started_at"] = pd.to_datetime(trip_data["started_at"])
trip_data["ended_at"] = pd.to_datetime(trip_data["ended_at"])

# %%
# Calculate the length of each ride/trip
trip_data["ride_length"] = trip_data["ended_at"] - trip_data["started_at"]
trip_data["ride_length"] = round(trip_data.ride_length/pd.Timedelta("60s"), 2)

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  datetime64[ns]
#  3   ended_at            359978 non-null  datetime64[ns]
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
#  13  ride_length         359978 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(7)
# memory usage: 38.4+ MB

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  7C00A93E10556E47  electric_bike 2021-11-27 13:27:38 2021-11-27 13:46:38
# 1  90854840DFD508BA  electric_bike 2021-11-27 13:38:25 2021-11-27 13:56:10
# 2  0A7D10CDD144061C  electric_bike 2021-11-26 22:03:34 2021-11-26 22:05:56
# 3  2F3BE33085BCFF02  electric_bike 2021-11-27 09:56:49 2021-11-27 10:01:50
# 4  D67B4781A19928D4  electric_bike 2021-11-26 19:09:28 2021-11-26 19:30:41
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual  ride_length  \
# 0      41.93     -87.72    41.96   -87.73        casual        19.00
# 1      41.96     -87.70    41.92   -87.70        casual        17.75
# 2      41.96     -87.70    41.96   -87.70        casual         2.37
# 3      41.94     -87.79    41.93   -87.79        casual         5.02
# 4      41.90     -87.63    41.88   -87.62        casual        21.22
#
#    day_of_week
# 0            5
# 1            5
# 2            4
# 3            5
# 4            4

# %%
trip_data["day_of_week"] = trip_data.started_at.dt.weekday

# %%
def process_files(files: list, path: str):
    """
       Helper function for working with multiple csv files to import to a Pandas Dataframe and running
       basic exploratory analysis.  All data in the files need to be of identical structure.  Checks and
       transforms data types.  Provides a quick glimpse at the bike usage, customer usage, and which bikes
       do customers use.
       
       Parameters
       ===============
       files: list
           list of files to upload
       path: str
           path of the directory where the files are stored 
    """
    
    for file in files:
        file_path = path + file
        df = pd.read_csv(file_path)
        trip_date = file[:6]
        print("="*50)
        print("     Beginning Cyclistic Trip Data EDA.......")
        print("="*50)
        print(f"Month: {trip_date[-2:]}")
        print(f" Year: {trip_date[:4]}")
        print("="*50)
        
        print(df.info())
        df.convert_dtypes()
        print("-"*50)
        
        print("        Percentage of Bike Usage by Type")
        print("-"*50)
        print(df["rideable_type"].value_counts(normalize=True))
        print("-"*50)
        
        print("          Percentage of Customer Type")
        print("-"*50)
        print(df["member_casual"].value_counts(normalize=True))
        print("-"*50)
        
        print("       Type of Bike Used by Customer Type")
        print("-"*50)
        print(df.groupby(["rideable_type", "member_casual"])["member_casual"].count().unstack())
        print("-"*50)
        
        # Transform the 'started_at' and 'ended_at' to datetime objects
        df["started_at"] = pd.to_datetime(df["started_at"])
        df["ended_at"] = pd.to_datetime(df["ended_at"])
        
        # Calculate the length of each ride/trip
        df["ride_length"] = df["ended_at"] - df["started_at"]
        df["ride_length"] = round(df.ride_length/pd.Timedelta("60s"), 2)
        
        # Calculate the day of the week (Monday=0,.....,Sunday=6)
        df["day_of_week"] = df.started_at.dt.weekday
        
        print("="*50)
        print("            Initial EDA Results........")
        print("="*50)
        print(df.info())
        print("-"*50)
        print(df.describe(include="all", datetime_is_numeric=True))
        print("="*50)
        return None

# %%
process_files(tripdata_files, dir_path)
# Out:
# ==================================================
#      Beginning Cyclistic Trip Data EDA.......
# ==================================================
# Month: 11
#  Year: 2021
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  object
#  3   ended_at            359978 non-null  object
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 35.7+ MB
# None
# --------------------------------------------------
#         Percentage of Bike Usage by Type
# --------------------------------------------------
# electric_bike    0.550936
# classic_bike     0.427912
# docked_bike      0.021151
# Name: rideable_type, dtype: float64
# --------------------------------------------------
#           Percentage of Customer Type
# --------------------------------------------------
# member    0.702957
# casual    0.297043
# Name: member_casual, dtype: float64
# --------------------------------------------------
#        Type of Bike Used by Customer Type
# --------------------------------------------------
# member_casual   casual    member
# rideable_type
# classic_bike   31866.0  122173.0
# docked_bike     7614.0       NaN
# electric_bike  67449.0  130876.0
# --------------------------------------------------
# ==================================================
#             Initial EDA Results........
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  datetime64[ns]
#  3   ended_at            359978 non-null  datetime64[ns]
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
#  13  ride_length         359978 non-null  float64
#  14  day_of_week         359978 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(7)
# memory usage: 41.2+ MB
# None
# --------------------------------------------------
#                  ride_id  rideable_type                     started_at  \
# count             359978         359978                         359978
# unique            359978              3                            NaN
# top     7C00A93E10556E47  electric_bike                            NaN
# freq                   1         198325                            NaN
# mean                 NaN            NaN  2021-11-13 21:27:31.154217728
# min                  NaN            NaN            2021-11-01 00:00:14
# 25%                  NaN            NaN  2021-11-06 17:34:18.249999872
# 50%                  NaN            NaN     2021-11-12 08:32:12.500000
# 75%                  NaN            NaN            2021-11-20 13:39:34
# max                  NaN            NaN            2021-11-30 23:59:56
# std                  NaN            NaN                            NaN
#
#                              ended_at   start_station_name start_station_id  \
# count                          359978               284688           284688
# unique                            NaN                  815              815
# top                               NaN  Ellis Ave & 60th St     KA1503000014
# freq                              NaN                 3095             3095
# mean    2021-11-13 21:42:19.903130112                  NaN              NaN
# min               2021-11-01 00:04:06                  NaN              NaN
# 25%     2021-11-06 17:53:19.750000128                  NaN              NaN
# 50%        2021-11-12 08:46:55.500000                  NaN              NaN
# 75%     2021-11-20 13:57:54.750000128                  NaN              NaN
# max               2021-12-02 06:41:33                  NaN              NaN
# std                               NaN                  NaN              NaN
#
#            end_station_name end_station_id      start_lat      start_lng  \
# count                280791         280791  359978.000000  359978.000000
# unique                  805            805            NaN            NaN
# top     Ellis Ave & 60th St   KA1503000014            NaN            NaN
# freq                   3002           3002            NaN            NaN
# mean                    NaN            NaN      41.893770     -87.647342
# min                     NaN            NaN      41.648501     -87.840000
# 25%                     NaN            NaN      41.877726     -87.663832
# 50%                     NaN            NaN      41.894666     -87.643107
# 75%                     NaN            NaN      41.925602     -87.627722
# max                     NaN            NaN      42.070000     -87.528232
# std                     NaN            NaN       0.052579       0.033397
#
#               end_lat        end_lng member_casual    ride_length  \
# count   359787.000000  359787.000000        359978  359978.000000
# unique            NaN            NaN             2            NaN
# top               NaN            NaN        member            NaN
# freq              NaN            NaN        253049            NaN
# mean        41.893900     -87.647543           NaN      14.812490
# min         41.390000     -88.970000           NaN     -58.030000
# 25%         41.877850     -87.663923           NaN       5.030000
# 50%         41.894683     -87.643118           NaN       8.580000
# 75%         41.925602     -87.627754           NaN      15.100000
# max         42.120000     -87.528232           NaN   34997.720000
# std          0.052618       0.033608           NaN     122.280158
#
#           day_of_week
# count   359978.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         2.743429
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max          6.000000
# std          2.025019
# ==================================================

# %%
for file in tripdata_files:
    file_path = dir_path + file
    df = pd.read_csv(file_path)
    trip_date = file[:6]
    print("="*50)
    print("                 Beginning EDA.......")
    print("="*50)
    print(f"Month: {trip_date[-2:]}")
    print(f" Year: {trip_date[:4]}")
    print("="*50)
    
    print(df.info())
    df.convert_dtypes()
    print("-"*50)
    
    print("        Percentage of Bike Usage by Type")
    print("-"*50)
    print(df["rideable_type"].value_counts(normalize=True))
    print("-"*50)
    
    print("          Percentage of Customer Type")
    print("-"*50)
    print(df["member_casual"].value_counts(normalize=True))
    print("-"*50)
    
    print("         Type of Bike Used by Customer Type")
    print("-"*50)
    print(df.groupby(["rideable_type", "member_casual"])["member_casual"].count().unstack())
    print("-"*50)
    
    # Transform the 'started_at' and 'ended_at' to datetime objects
    df["started_at"] = pd.to_datetime(df["started_at"])
    df["ended_at"] = pd.to_datetime(df["ended_at"])
    
    # Calculate the length of each ride/trip
    df["ride_length"] = df["ended_at"] - df["started_at"]
    df["ride_length"] = round(df.ride_length/pd.Timedelta("60s"), 2)
    
    # Calculate the day of the week (Monday=0,.....,Sunday=6)
    df["day_of_week"] = df.started_at.dt.weekday
    
    print("-"*50)
    print("              Initial Results........")
    print(df.info())
    print("-"*50)
    print(df.describe(include="all", datetime_is_numeric=True))
    print("="*50)
    break
# Out:
# ==================================================
#                  Beginning EDA.......
# ==================================================
# Month: 11
#  Year: 2021
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  object
#  3   ended_at            359978 non-null  object
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 35.7+ MB
# None
# --------------------------------------------------
#         Percentage of Bike Usage by Type
# --------------------------------------------------
# electric_bike    0.550936
# classic_bike     0.427912
# docked_bike      0.021151
# Name: rideable_type, dtype: float64
# --------------------------------------------------
#           Percentage of Customer Type
# --------------------------------------------------
# member    0.702957
# casual    0.297043
# Name: member_casual, dtype: float64
# --------------------------------------------------
#          Type of Bike Used by Customer Type
# --------------------------------------------------
# member_casual   casual    member
# rideable_type
# classic_bike   31866.0  122173.0
# docked_bike     7614.0       NaN
# electric_bike  67449.0  130876.0
# --------------------------------------------------
# --------------------------------------------------
#               Initial Results........
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  datetime64[ns]
#  3   ended_at            359978 non-null  datetime64[ns]
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
#  13  ride_length         359978 non-null  float64
#  14  day_of_week         359978 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(7)
# memory usage: 41.2+ MB
# None
# --------------------------------------------------
#                  ride_id  rideable_type                     started_at  \
# count             359978         359978                         359978
# unique            359978              3                            NaN
# top     7C00A93E10556E47  electric_bike                            NaN
# freq                   1         198325                            NaN
# mean                 NaN            NaN  2021-11-13 21:27:31.154217728
# min                  NaN            NaN            2021-11-01 00:00:14
# 25%                  NaN            NaN  2021-11-06 17:34:18.249999872
# 50%                  NaN            NaN     2021-11-12 08:32:12.500000
# 75%                  NaN            NaN            2021-11-20 13:39:34
# max                  NaN            NaN            2021-11-30 23:59:56
# std                  NaN            NaN                            NaN
#
#                              ended_at   start_station_name start_station_id  \
# count                          359978               284688           284688
# unique                            NaN                  815              815
# top                               NaN  Ellis Ave & 60th St     KA1503000014
# freq                              NaN                 3095             3095
# mean    2021-11-13 21:42:19.903130112                  NaN              NaN
# min               2021-11-01 00:04:06                  NaN              NaN
# 25%     2021-11-06 17:53:19.750000128                  NaN              NaN
# 50%        2021-11-12 08:46:55.500000                  NaN              NaN
# 75%     2021-11-20 13:57:54.750000128                  NaN              NaN
# max               2021-12-02 06:41:33                  NaN              NaN
# std                               NaN                  NaN              NaN
#
#            end_station_name end_station_id      start_lat      start_lng  \
# count                280791         280791  359978.000000  359978.000000
# unique                  805            805            NaN            NaN
# top     Ellis Ave & 60th St   KA1503000014            NaN            NaN
# freq                   3002           3002            NaN            NaN
# mean                    NaN            NaN      41.893770     -87.647342
# min                     NaN            NaN      41.648501     -87.840000
# 25%                     NaN            NaN      41.877726     -87.663832
# 50%                     NaN            NaN      41.894666     -87.643107
# 75%                     NaN            NaN      41.925602     -87.627722
# max                     NaN            NaN      42.070000     -87.528232
# std                     NaN            NaN       0.052579       0.033397
#
#               end_lat        end_lng member_casual    ride_length  \
# count   359787.000000  359787.000000        359978  359978.000000
# unique            NaN            NaN             2            NaN
# top               NaN            NaN        member            NaN
# freq              NaN            NaN        253049            NaN
# mean        41.893900     -87.647543           NaN      14.812490
# min         41.390000     -88.970000           NaN     -58.030000
# 25%         41.877850     -87.663923           NaN       5.030000
# 50%         41.894683     -87.643118           NaN       8.580000
# 75%         41.925602     -87.627754           NaN      15.100000
# max         42.120000     -87.528232           NaN   34997.720000
# std          0.052618       0.033608           NaN     122.280158
#
#           day_of_week
# count   359978.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         2.743429
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max          6.000000
# std          2.025019
# ==================================================

# %%
trip_data.rename(columns = {"member_casual" : "customer_type"}, inplace = True)

# %%
trip_data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  7C00A93E10556E47  electric_bike 2021-11-27 13:27:38 2021-11-27 13:46:38
# 1  90854840DFD508BA  electric_bike 2021-11-27 13:38:25 2021-11-27 13:56:10
# 2  0A7D10CDD144061C  electric_bike 2021-11-26 22:03:34 2021-11-26 22:05:56
# 3  2F3BE33085BCFF02  electric_bike 2021-11-27 09:56:49 2021-11-27 10:01:50
# 4  D67B4781A19928D4  electric_bike 2021-11-26 19:09:28 2021-11-26 19:30:41
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng customer_type  ride_length  \
# 0      41.93     -87.72    41.96   -87.73        casual        19.00
# 1      41.96     -87.70    41.92   -87.70        casual        17.75
# 2      41.96     -87.70    41.96   -87.70        casual         2.37
# 3      41.94     -87.79    41.93   -87.79        casual         5.02
# 4      41.90     -87.63    41.88   -87.62        casual        21.22
#
#    day_of_week
# 0            5
# 1            5
# 2            4
# 3            5
# 4            4
